# %%
import matplotlib.pyplot as plt

def exp_mod(base, exp, mod):
    return pow(base, exp) % mod

start = 1
end = 100
b = 4
N = 55
xs = [i for i in range(start, end)]
ys = [exp_mod(b, x, N) for x in xs]

plt.figure(figsize=(18, 10))
plt.plot(xs, ys)
